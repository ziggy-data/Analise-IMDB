# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
tmdb = pd.read_csv('dados/tmdb_5000_movies.csv')

# %%
tmdb.head(3)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# 2  [{"id": 470, "name": "spy"}, {"id": 818, "name...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
# ...

# %%
tmdb.describe()
# Out:
#              budget             id   popularity       revenue      runtime  \
# count  4.803000e+03    4803.000000  4803.000000  4.803000e+03  4801.000000
# mean   2.904504e+07   57165.484281    21.492301  8.226064e+07   106.875859
# std    4.072239e+07   88694.614033    31.816650  1.628571e+08    22.611935
# min    0.000000e+00       5.000000     0.000000  0.000000e+00     0.000000
# 25%    7.900000e+05    9014.500000     4.668070  0.000000e+00    94.000000
# 50%    1.500000e+07   14629.000000    12.921594  1.917000e+07   103.000000
# 75%    4.000000e+07   58610.500000    28.313505  9.291719e+07   118.000000
# max    3.800000e+08  459488.000000   875.581305  2.787965e+09   338.000000
#
#        vote_average    vote_count
# count   4803.000000   4803.000000
# mean       6.092172    690.217989
# std        1.194612   1234.585891
# min        0.000000      0.000000
# 25%        5.600000     54.000000
# 50%        6.200000    235.000000
# 75%        6.800000    737.000000
# ...

# %%
ax = sns.histplot(tmdb.vote_average, kde=True, stat="frequency")
ax.set(xlabel='Nota média',ylabel='Frequência')
plt.show()

# %%
ax = sns.histplot(tmdb.vote_average,stat='count')
ax.set(xlabel='Nota média',ylabel='Densidade')
plt.show()

# %%
ax = sns.boxplot(x=tmdb.vote_average)
ax.set_xlabel('Média da notas dos filmes')
ax.set_title('Distribuição de nota média dos filmes do TMDB 5000')
plt.show()

# %%
tmdb.query("vote_count == 0")
# Out:
#        budget                                             genres  \
# 1464        0  [{"id": 18, "name": "Drama"}, {"id": 80, "name...
# 3669        0  [{"id": 35, "name": "Comedy"}, {"id": 18, "nam...
# 3670        0                  [{"id": 10751, "name": "Family"}]
# 3852        0                      [{"id": 18, "name": "Drama"}]
# 3855  3500000                [{"id": 99, "name": "Documentary"}]
# ...       ...                                                ...
# 4769        0  [{"id": 28, "name": "Action"}, {"id": 37, "nam...
# 4771        0                     [{"id": 27, "name": "Horror"}]
# 4780        0  [{"id": 53, "name": "Thriller"}, {"id": 80, "n...
# 4785        0                      [{"id": 18, "name": "Drama"}]
# 4794        0  [{"id": 53, "name": "Thriller"}, {"id": 27, "n...
#
#                            homepage      id  \
# 1464                            NaN  310706
# 3669  http://www.romeothemovie.com/  113406
# 3670                            NaN  447027
# ...

# %% [markdown]
# <strong>Percebemos uma estranhesa nos dados acima com média d notas sendo 10 ou 0 e ao análisar percebemos que a quantidade de votos foram baixas ou estão vazias (sendo maioria 0)</strong>

# %%
tmdb_mais_dez = tmdb.query("vote_count >= 10")
tmdb_mais_dez.describe().round(4)
# Out:
#              budget           id  popularity       revenue    runtime  \
# count  4.392000e+03    4392.0000   4392.0000  4.392000e+03  4391.0000
# mean   3.164545e+07   49204.1200     23.4488  8.990969e+07   108.4309
# std    4.162736e+07   80136.2498     32.5922  1.682870e+08    21.0147
# min    0.000000e+00       5.0000      0.0117  0.000000e+00     0.0000
# 25%    2.895962e+06    8403.5000      6.5122  1.365700e+04    95.0000
# 50%    1.700000e+07   13084.5000     14.8278  2.685837e+07   105.0000
# 75%    4.200000e+07   46831.2500     30.2583  1.022818e+08   118.5000
# max    3.800000e+08  417859.0000    875.5813  2.787965e+09   338.0000
#
#        vote_average  vote_count
# count     4392.0000   4392.0000
# mean         6.2269    754.4417
# std          0.8932   1272.2638
# min          1.9000     10.0000
# 25%          5.7000     83.7500
# 50%          6.3000    288.5000
# 75%          6.8000    831.0000
# max          8.5000  13752.0000

# %%
ax = sns.histplot(x=tmdb_mais_dez.vote_average,stat="count",kde=True)
ax.set_xlabel('Média da notas dos filmes')
ax.set_ylabel('Quantidade')
ax.set_title('Distribuição de nota média dos filmes do TMDB 5000 entre os filmes com mais de 10 votos')
plt.show()

# %%
ax = sns.histplot(x=tmdb_mais_dez.vote_average,
                  cumulative=True,
                  kde=True,
                  bins=70)
ax.set_xlabel('Média da notas dos filmes acumulada')
ax.set_ylabel('Quantidade')
ax.set_title('Proporção acumulada de nota média dos filmes no TMDB 5k')
plt.show()

# %%
ax = sns.boxplot(x=tmdb_mais_dez.vote_average)
ax.set_xlabel('Média da notas dos filmes')
ax.set_title('Distribuição de nota média dos filmes do TMDB 5000 entre os filmes com mais de 10 votos')
plt.show()

# %% [markdown]
# analisaremos tbm o movie lens

# %%
notas = pd.read_csv('dados/ratings.csv')
notas.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
media_nota = notas.groupby('movieId').mean().rating
media_nota.head()
# Out:
# movieId
# 1    3.920930
# 2    3.431818
# 3    3.259615
# 4    2.357143
# 5    3.071429
# Name: rating, dtype: float64

# %%
ax = sns.histplot(x=media_nota.values,stat="count",kde=True)
ax.set_xlabel('Média da notas dos filmes')
ax.set_ylabel('Quantidade')
ax.set_title('Distribuição de nota média dos filmes no Movielens 100k')
plt.show()

# %%
quantidade_de_votos_por_filme = notas.groupby('movieId').count()
filmes_com_ate_10_votos = quantidade_de_votos_por_filme.query('rating >= 10').index
filmes_com_ate_10_votos.values
# Out:
# array([     1,      2,      3, ..., 177765, 179819, 187593], dtype=int64)

# %%
nota_media_com_pelo_menos_10_votos = media_nota.loc[filmes_com_ate_10_votos.values]
nota_media_com_pelo_menos_10_votos
# Out:
# movieId
# 1         3.920930
# 2         3.431818
# 3         3.259615
# 5         3.071429
# 6         3.946078
#             ...
# 174055    3.423077
# 176371    3.805556
# 177765    3.538462
# 179819    3.125000
# 187593    3.875000
# Name: rating, Length: 2269, dtype: float64

# %%
ax = sns.histplot(x=nota_media_com_pelo_menos_10_votos.values,stat="count",kde=True,bins=70)
ax.set_xlabel('Média da notas dos filmes')
ax.set_ylabel('Quantidade')
ax.set_title('Distribuição de nota média dos filmes no Movielens 100k')
plt.show()

# %%
ax = sns.histplot(x=nota_media_com_pelo_menos_10_votos.values,
                  cumulative=True,
                  kde=True,
                  bins=70)
ax.set_xlabel('Média da notas dos filmes')
ax.set_ylabel('Quantidade')
ax.set_title('Proporção acumulada de nota média dos filmes no Movielens 100k')
plt.show()

# %%
ax = sns.boxplot(x=nota_media_com_pelo_menos_10_votos.values)
ax.set_xlabel('Média da notas dos filmes')
ax.set_title('Distribuição de nota média dos filmes do movielens 100k entre os filmes com mais de 10 votos')
plt.show()

# %% [markdown]
# ## analisando a distribuição dos dados capturados de outros campos do TMDB

# %%
ax = sns.histplot(x=tmdb_mais_dez.vote_count,stat="count",kde=True,bins=70)
ax.set_xlabel('Numero de votos')
ax.set_ylabel('Quantidade')
ax.set_title('Distribuição de notas dos filmes no TMDB 5k')
plt.show()

# %%
ax = sns.histplot(x=tmdb.query('budget > 0').budget,stat="count",kde=True,bins=70)
ax.set_xlabel('Numero de votos')
ax.set_ylabel('Quantidade')
ax.set_title('Distribuição de notas dos filmes no TMDB 5k')
plt.show()

# %%
tmdb.popularity
# Out:
# 0       150.437577
# 1       139.082615
# 2       107.376788
# 3       112.312950
# 4        43.926995
#            ...
# 4798     14.269792
# 4799      0.642552
# 4800      1.444476
# 4801      0.857008
# 4802      1.929883
# Name: popularity, Length: 4803, dtype: float64

# %%
tmdb.query('popularity == 0')
# Out:
#       budget genres homepage      id keywords original_language  \
# 4553       0     []      NaN  380097       []                en
#
#                   original_title  \
# 4553  America Is Still the Place
#
#                                                overview  popularity  \
# 4553  1971 post civil rights San Francisco seemed li...         0.0
#
#      production_companies production_countries release_date  revenue  runtime  \
# 4553                   []                   []          NaN        0      0.0
#
#      spoken_languages    status tagline                       title  \
# 4553               []  Released     NaN  America Is Still the Place
#
#       vote_average  vote_count
# 4553           0.0           0

# %% [markdown]
# Já que existe apenas um dado com popularidade igual a zero, iremos supor então que esse dado realmente tem nenhuma popularidade e não será deletado.

# %%
ax = sns.histplot(x=tmdb.popularity,stat="count",kde=True,bins=70)
ax.set_xlabel('Popularidade')
ax.set_ylabel('Quantidade')
ax.set_title('Distribuição de notas dos filmes no TMDB 5k')
plt.show()

# %%
ax = sns.histplot(x=tmdb.runtime,stat="count",kde=True,bins=70)
ax.set_xlabel('Tempo de duração')
ax.set_ylabel('Quantidade')
ax.set_title('Distribuição de notas dos filmes no TMDB 5k')
plt.show()

# %% [markdown]
# Deveria trazer um erro mas ele interpretou, o erro deveria ser " ValueError: cannot convert float NaN to integer ", e podemos ver filmes com zero de duração.

# %%
tmdb.runtime.isnull().sum()
# Out:
# 2

# %%
tmdb.query('runtime == 0').runtime
# Out:
# 1011    0.0
# 3112    0.0
# 3669    0.0
# 3809    0.0
# 3953    0.0
# 3992    0.0
# 4068    0.0
# 4118    0.0
# 4205    0.0
# 4210    0.0
# 4241    0.0
# 4313    0.0
# 4318    0.0
# 4322    0.0
# 4328    0.0
# 4405    0.0
# 4435    0.0
# 4458    0.0
# 4502    0.0
# 4504    0.0
# 4553    0.0
# 4558    0.0
# 4564    0.0
# 4566    0.0
# 4569    0.0
# 4571    0.0
# 4581    0.0
# 4584    0.0
# 4611    0.0
# 4620    0.0
# 4633    0.0
# 4657    0.0
# 4658    0.0
# 4662    0.0
# 4729    0.0
# Name: runtime, dtype: float64

# %%
ax = sns.histplot(x=tmdb.query('runtime > 0').runtime.dropna(),stat="count",kde=True,bins=70)
ax.set_xlabel('Tempo de duração')
ax.set_ylabel('Quantidade')
ax.set_title('Distribuição de notas dos filmes no TMDB 5k')
plt.show()

# %%
ax = sns.histplot(x=tmdb.query('runtime > 0').runtime.dropna(),stat="probability",cumulative=True,kde=True,bins=70)
ax.set_xlabel('Tempo de duração')
ax.set_ylabel('Proporção de duração')
ax.set_title('Distribuição de notas dos filmes no TMDB 5k')
plt.show()

# %%
tmdb.query('runtime > 0').runtime.dropna().quantile(0.8)
# Out:
# 121.0

# %% [markdown]
# analisando movie lens com pelo menos 10 votos

# %%
print('Média dos filmes com pelo menos 10 votos: {:.3f}'.
      format(nota_media_com_pelo_menos_10_votos.mean()))
# Out:
# Média dos filmes com pelo menos 10 votos: 3.432

# %%
medias = list()

np.random.seed(75243)
temp = nota_media_com_pelo_menos_10_votos.sample(frac=1)

medias = [temp[0:i].mean() for i in range(1,len(temp))]

plt.plot(medias)

# %%
from statsmodels.stats.weightstats import zconfint  #intervalo de confiança

zconfint(nota_media_com_pelo_menos_10_votos)

#dado o conjunto de dados e acreditando que é  uma amostra grande suficiente para
#aplicar esse tipo d teste, esse teste EXIGE normalidade, dados grande. 
#entao temos esse intervalo de confienaça pelos filmes EM GERAL.
# Out:
# (3.4112459477469557, 3.452854733323563)

# %%
from statsmodels.stats.weightstats import DescrStatsW
decricao_todos_com_10_votos = DescrStatsW(nota_media_com_pelo_menos_10_votos)
decricao_todos_com_10_votos.tconfint_mean()
# Out:
# (3.411234839229379, 3.4528658418411378)

# %% [markdown]
# ## vamos ver o filme 1...

# %%
filmes = pd.read_csv('dados/movies.csv')
filmes.query('movieId==1')
# Out:
#    movieId             title                                       genres
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy

# %%
notas1 = notas.query('movieId==1')

ax = sns.histplot(x=notas1.rating,stat="count",kde=True,bins=70)
ax.set_xlabel('Notas')
ax.set_ylabel('Quantidade')
ax.set_title('Distribuição das notas do Toy Story')
plt.show()

# %%
ax = sns.boxplot(x=notas1.rating)
ax.set_xlabel('Notas')
ax.set_title('Distribuição das notas do Toy Story')
plt.show()

# %% [markdown]
# # teste estatístico

# %%
notas1.rating.mean()
# Out:
# 3.9209302325581397

# %%
notas1.rating.count()
# Out:
# 215

# %%
zconfint(notas1.rating)
# Out:
# (3.8093359183563402, 4.032524546759939)

# %%
#esse teste é uma afirmação, 'acredito que a nota do toy story seja a nota media de todos os filmes'
#nesse teste estamos conferindo com um h0 de igualdade(=) e sendo BICAUDAL
#nesse exemplo a pergunta é 'qual é probabilidade de 3,432 aparecer no intervalo de confianca'
from statsmodels.stats.weightstats import ztest
statistic, p_value = ztest(notas1.rating, value=3.432)
print('o valor d p-valor = ',p_value)
# Out:
# o valor d p-valor =  8.909392288271546e-18

# %%
if p_value<=0.05:
    print('rejeitar hipótese (menor que 0,05)')
else:
    print('aceitar hipótese(maior que 0.05)')
# Out:
# rejeitar hipótese (menor que 0,05)

# %% [markdown]
# Em BigData é mais interessante estudar os aspectos:a possibilidade de igualdade (2 linhas acima), o intervalo de confiança na (3 linha superior), e visualizações GRÁFICAS DAS DISTRIBUIÇOES

# %%
np.random.seed(75243)
temp = notas1.sample(frac=1).rating

def calcula_teste(i):
    media = temp[0:i].mean()
    stat, p = ztest(temp[0:i], value= 3.432)
    return (i,media,p)

valores = np.array([calcula_teste(i) for i in range(2,len(temp))])

plt.plot(valores[:,0], valores[:,1])
plt.plot(valores[:,0], valores[:,2])
plt.hlines(y=0.05, xmin=2, xmax=len(temp), colors='r')

# %% [markdown]
# Perceba que, antes de chegarmos a 50 amostras, o p value é bastante instável. Lembre-se que estamos analisando esse p value de acordo com o valor 0.05 (5%). Então, utilizaremos a função plt.hlines() para delimitarmos uma linha referencial ao longo do eixo y do nosso gráfico.
#
# Para isso, passaremos 0.05 como valor de y; 2 como valor de xmin, len(temp) como valor de xmax; e r como valor de colors (de modo que a linha traçada seja vermelha).
#
# Agora, analisando nosso gráfico, podemos enxergar em que pontos o p value é maior que 0.05. Repare que tivemos sorte (ou azar) de que a ordem das notas fez com que a média começasse muito alta, caísse, ficasse próxima à média de todos os filmes e depois se distanciasse novamente.
#
# O Teste Z é realizado quando temos um número grande de amostras - por exemplo, a partir de 50.
#
# Ou seja, na prática esse tipo de gráfico não é executado, nós apenas queríamos visualizar as consequências de trabalharmos com um conjunto pequeno de dados. Uma possibilidade seria cairmos em uma situação na qual não teríamos evidências suficientes para descartar a hipótese nula (de que a média é igual a 3.4320503405352603), concluindo, portanto, que a média do Toy Story é igual àquela usada como referência.
#
# Nessa situação, poderia-se afirmar, a partir do Teste Z:
#
# que não há evidências para descartar a hipótese nula
# que não há dados suficientes para tirar essa conclusão
# É importante, em nossas análises, evidenciarmos qual o tamanho da amostra e qual o p value para que as pessoas tenham uma noção clara do comportamento dos dados.
#
# (O Teste Z é ideal quando temos grandes quantidades de dados.)
#
# (O Teste T é utilizado quando temos uma amostra pequena de dados!)

# %% [markdown]
# ## Comparação entre dois conjuntos de amostras

# %%
#como pegar um intervalo atraves d médias entre 2 distribuições e verificar o quão diferentes elas são
zconfint(notas1.rating, notas.rating)
# Out:
# (0.2799245129192442, 0.5588219849631111)

# %% [markdown]
# ele diz que a média das notas1 está entre 0.27 e 0.55 mais alta que a média da distribuição de todas as notas. ESSA É A DIFERENÇA ENTRE OS DOIS

# %%
#agr a diferença com p value
ztest(notas1.rating, notas.rating)
# Out:
# (5.894327101501841, 3.762112778881965e-09)

# %%
from scipy.stats import ttest_ind
ttest_ind(notas.rating,notas1.rating)
# Out:
# Ttest_indResult(statistic=-5.894327101501841, pvalue=3.774003138720876e-09)

# %%
descr_todas_as_notas = DescrStatsW(notas.rating)
descr_toystory = DescrStatsW(notas1.rating)
comparacao = descr_todas_as_notas.get_compare(descr_toystory)
comparacao.summary()
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# Nesse p value = 0.000, descarta a hipótese que são iguais e temos tambem o intervalo de confiaça entre -0.559 até -0.280

# %%
# ele ja vem por padrao o t test ativo 
comparacao.summary(use_t=True)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
plt.boxplot([notas.rating, notas1.rating],labels=['Todas as notas','Toy Story'])
plt.show()

# %% [markdown]
# ## intervalo de confiança

# %% [markdown]
# Como um intervalo de confiança pode enganar com poucas amostras (na linha abaixo)

# %%
plt.boxplot([notas.rating, notas1.rating[3:12]],labels=['Todas as notas','Toy Story(do 3 ao 12)'])
plt.show()

# %%
descr_todas_as_notas = DescrStatsW(notas.rating)
descr_toystory = DescrStatsW(notas1.rating)
comparacao = descr_todas_as_notas.get_compare(descr_toystory)
comparacao.summary(use_t=True)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# na conclusão dessa situação nos poderiamos concluir que não temos dados suficientes para concluir ou que não temos evidencia contra a hipotese nula.

# %% [markdown]
# ## Comparação de média de dois filmes

# %%
notas1= notas.query("movieId == 1")
notas72226 = notas.query("movieId == 72226")
notas593 = notas.query("movieId == 593")

plt.boxplot([notas1.rating,notas593.rating,notas72226.rating], labels=['ToyStory','The silent of the lambs','Fantastic Mr.Fox'])
plt.show()

# %%
notas72226.describe()
# Out:
#            userId  movieId     rating     timestamp
# count   18.000000     18.0  18.000000  1.800000e+01
# mean   329.722222  72226.0   4.083333  1.395218e+09
# std    174.748157      0.0   0.895249  9.459862e+07
# min     73.000000  72226.0   1.500000  1.262899e+09
# 25%    167.000000  72226.0   4.000000  1.279706e+09
# 50%    326.000000  72226.0   4.250000  1.441777e+09
# 75%    466.250000  72226.0   4.500000  1.471770e+09
# max    610.000000  72226.0   5.000000  1.498522e+09

# %%
sns.boxplot(x = "movieId", y = "rating", data = notas.query("movieId in (1, 593, 72226)"))
# Out:
# <AxesSubplot:xlabel='movieId', ylabel='rating'>

# %%
#essa celula é o resultado decente, os outro 2 abaixo são meio inuteis pq passa o intervalo d confiança (0.330, 0.566)
descr_1 = DescrStatsW(notas1.rating)
descr_593 = DescrStatsW(notas593.rating)
comparacao = descr_1.get_compare(descr_593)
comparacao.summary(use_t=False)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# Encontramos uma diferença estatistica aplicando um z teste com p value significante de 0.002, e o intervalo inclui tanto a chance do filme ser pior, quanto a chance dele ser melhor.

# %%
descr_72226 = DescrStatsW(notas72226.rating)
descr_593 = DescrStatsW(notas593.rating)
comparacao = descr_72226.get_compare(descr_593)
comparacao.summary(use_t=False)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# Encontramos uma diferença estatistica aplicando um z teste com p value de 0.708 , ou seja, maior que 0.05 (95%) previamente definido e um intervalo de confiança entre -0.486 e -0.330.

# %%
comparacao = descr_72226.get_compare(descr_1)
comparacao.summary(use_t=False)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %% [markdown]
# Da mesma forma, não temos uma diferença significativa (0.430), e o intervalo também inclui aquelas duas possibilidades. Portanto, a única diferença que encontramos nos nossos dados foi entre os filmes Toy Story e Silence of the Lambs - na qual o último filme é melhor (talvez um pouco melhor, talvez razoavelmente melhor).

# %%
notas.query("movieId in (1, 593, 72226)").groupby("movieId").count()
# Out:
#          userId  rating  timestamp
# movieId
# 1           215     215        215
# 593         279     279        279
# 72226        18      18         18

# %% [markdown]
# Repare que os filmes Toy Story e Silence of the Lambs possuem uma quantidade substancial de notas, enquanto Fantastic Mr. Fox possui apenas 18 notas. Por isso, é mais interessante utilizarmos o Teste T quando formos trabalhar com os dados desse filme.
#
# Rodar o teste sem a certeza de que poderíamos utilizá-lo acabou influenciando na nossa leitura. Portanto, devemos sempre explorar os nossos dados de forma a garantir que os testes sejam executados corretamente.
#
# Se repetirmos nossos testes com use_t=True nos momentos em que descr_72226 aparece, o p value continuará indicando que, nessa situação, a diferença não é significante. Porém, devemos sempre tomar cuidado com a maneira que atuamos na estatística.

# %%
descr_72226 = DescrStatsW(notas72226.rating)
descr_593 = DescrStatsW(notas593.rating)
comparacao = descr_72226.get_compare(descr_593)
comparacao.summary(use_t=True)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
comparacao = descr_72226.get_compare(descr_1)
comparacao.summary(use_t=True)
# Out:
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
from scipy.stats import normaltest

stat, p_value = normaltest(notas1.rating)
print(stat, p_value)
# Out:
# 18.220369223286593 0.00011053430732728716

# %%
from scipy.stats import ranksums
ranksums(notas1.rating, notas593.rating)
# Out:
# RanksumsResult(statistic=-3.5930962013771377, pvalue=0.0003267718756440693)
